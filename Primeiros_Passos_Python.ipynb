# %% [markdown]
# <a href="https://colab.research.google.com/github/radaspinheiro-arch/meu-primeiro--projeto-c/blob/main/Primeiros_Passos_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definindo os dados da sua loja
loja = "AchadinhosrDEUSk"
vendas = 25
valor_item = 12.50

# Calculando o faturamento total
faturamento = vendas * valor_item

print(f"--- Relatório da Loja {loja} ---")
print(f"Total de vendas: {vendas}")
print(f"Faturamento bruto: R$ {faturamento:.2f}")
# Out:
# --- Relatório da Loja AchadinhosrDEUSk ---
# Total de vendas: 25
# Faturamento bruto: R$ 312.50
